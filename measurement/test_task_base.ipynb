# %%
import time
import sys
import os
path_project = "\\".join(os.getcwd().split("\\")[:-1])
# caution: path[0] is reserved for script path (or '' in REPL)
sys.path.insert(1, path_project)
from measurement.task_base import JobManager, DummyMeasurement

import matplotlib.pyplot as plt
import numpy as np
# Out:
# matplotlib data path: d:\ProgramData\Miniconda3\lib\site-packages\matplotlib\mpl-data
# CONFIGDIR=C:\Users\CCT\.matplotlib
# interactive is False
# platform is win32
# CACHEDIR=C:\Users\CCT\.matplotlib
# Using fontManager instance from C:\Users\CCT\.matplotlib\fontlist-v330.json

# %%
jobmanager = JobManager()
jobmanager.start()
dmmm1 = DummyMeasurement()
dmmm1.set_stoptime(2)
dmmm1.set_paraset(epicpara1=6565, epicpara2="I ate breakfast")
jobmanager.submit(dmmm1) 
time.sleep(2)
plt.plot(dmmm1.dataset["timestamp"], dmmm1.dataset["signal"])
jobmanager.stop(1)
# Out:
# Starting Job Manager.
# Attempt to submit job <measurement.task_base.DummyMeasurement object at 0x0000027374732820>
# Notifying process thread.
# Job <measurement.task_base.DummyMeasurement object at 0x0000027374732820> submitted.
# Attempt to fetch first job in queue.
# Found job <measurement.task_base.DummyMeasurement object at 0x0000027374732820>. Starting.
# Parameters are: {'epicpara1': 6565, 'epicpara2': 'I ate breakfast', 'volt_amp': 1, 'freq': 20.0, 'length': 100}
# this class name: DummyMeasurement
# Hello it's set up!
# total number of runs: 2147483647
# hey fake experiment-'DummyMeasurement-dumdefault' no.0
# I'm cooking some fake data
# Moving data to a data server if you have one
# hey fake experiment-'DummyMeasurement-dumdefault' no.1
# I'm cooking some fake data
# in task base measurement, state is wait
# Moving data to a data server if you have one
# hey fake experiment-'DummyMeasurement-dumdefault' no.2
# I'm cooking some fake data
# ...

# %%
jobmanager = JobManager()
jobmanager.start()
# Out:
# Starting Job Manager.

# %%
jobname = ["Alice", "Bob", "Cindy", "Don", "Eve"]
jobpriority = [4, 1, 2, 10, 5]
jobvar = [3,2,5,1,4]
jobs = []
for nn, pp, vv in zip(jobname, jobpriority, jobvar):
    jj = DummyMeasurement(name=nn)
    jj.set_priority(pp)
    jj.set_runnum(10)
    jj.set_paraset(epicpara1=6565, 
                   epicpara2=f"I ate {vv} appples", 
                   volt_amp=1,
                   freq=10.0*vv)
    jobs.append(jj)

for jj in jobs:
    jobmanager.submit(jj) 
jobmanager.remove(jobs[4])

time.sleep(0.1)
print(f"Jobs Running: {[dict(name=JobManager().running.get_name(), priority=JobManager().running.priority) ]}")
print(f"Jobs in queue: {[dict(name=job.get_name(), priority=job.priority) for job in JobManager().queue]}")
time.sleep(0.2)
print(f"Jobs Running: {[dict(name=JobManager().running.get_name(), priority=JobManager().running.priority) ]}")
print(f"Jobs in queue: {[dict(name=job.get_name(), priority=job.priority) for job in JobManager().queue]}")
time.sleep(10)
# Out:
# Attempt to submit job <measurement.task_base.DummyMeasurement object at 0x00000273768D3D90>
# Notifying process thread.
# Job <measurement.task_base.DummyMeasurement object at 0x00000273768D3D90> submitted.
# Attempt to submit job <measurement.task_base.DummyMeasurement object at 0x00000273768D3DF0>
# Notifying process thread.
# Job <measurement.task_base.DummyMeasurement object at 0x00000273768D3DF0> submitted.
# Attempt to submit job <measurement.task_base.DummyMeasurement object at 0x00000273768D3E20>
# Notifying process thread.
# Job <measurement.task_base.DummyMeasurement object at 0x00000273768D3E20> submitted.
# Attempt to submit job <measurement.task_base.DummyMeasurement object at 0x00000273768D3E50>
# Notifying process thread.
# Job <measurement.task_base.DummyMeasurement object at 0x00000273768D3E50> submitted.
# Attempt to submit job <measurement.task_base.DummyMeasurement object at 0x00000273768D3E80>
# Notifying process thread.
# ...

# %%
jobmanager.stop(1)
# Out:
# attempt to stop thread <StoppableThread(JobManager24-11-02_01h22m41, started 34552)>
# Caught notification.

# %%
for jj in jobs:
    print(jj.stateset)
    print(jj.paraset)
    print(jj.dataset)
# Out:
# {'priority': 4, 'state': 'done', 'time_run': 1.3049893379211426, 'time_stop': 3.4028235e+38, 'idx_run': 10, 'num_run': 10}
# {'epicpara1': 6565, 'epicpara2': 'I ate 3 appples', 'volt_amp': 1, 'freq': 30.0, 'length': 100}
# {'signal': array([ 0.25776537,  0.50038048,  0.66440076,  0.89369329,  0.95481271,
#         1.11539363,  0.99705243,  1.1315717 ,  1.20680006,  1.07869397,
#         1.05559291,  0.86914537,  0.76134374,  0.55962963,  0.2855183 ,
#         0.0969468 , -0.10612246, -0.28918228, -0.50753257, -0.65005492,
#        -0.81375844, -0.96174038, -1.06966269, -1.08159089, -1.29447058,
#        -1.01523179, -1.13801665, -0.98857878, -0.89526028, -0.6202871 ,
#        -0.42966615, -0.26927915, -0.03470948,  0.16921063,  0.39751077,
#         0.60987951,  0.82927537,  0.95004936,  1.06333925,  1.08499281,
#         1.00943471,  1.08637775,  1.11739907,  1.05175283,  0.81465738,
#         0.66968623,  0.55921972,  0.39259259,  0.17392298, -0.0427023 ,
# ...

# %%
for job in jobs:
    plt.plot(job.dataset["timestamp"], job.dataset["signal"], label=job.get_name())

plt.xlabel("Timestamp")
plt.ylabel("Signal")
plt.title("Signal vs Timestamp for each Job")
plt.legend()
plt.show()
# Out:
# findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0.
# findfont: score(FontEntry(fname='d:\\ProgramData\\Miniconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\cmmi10.ttf', name='cmmi10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# findfont: score(FontEntry(fname='d:\\ProgramData\\Miniconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXSizFiveSymReg.ttf', name='STIXSizeFiveSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# findfont: score(FontEntry(fname='d:\\ProgramData\\Miniconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXGeneralBolIta.ttf', name='STIXGeneral', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# ...
